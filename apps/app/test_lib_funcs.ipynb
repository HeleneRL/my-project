# %%
import os, sys
print("PYTHONPATH =", os.getenv("PYTHONPATH"))
# Out:
# PYTHONPATH = C:\Users\helen\Documents\PythonProjects\my-project\libs

# %%
from dasprocessor import detection
print("Success!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from dasprocessor import detection
#       2 print("Success!")
#
# File ~\Documents\PythonProjects\my-project\libs\dasprocessor\__init__.py:1
# ----> 1 from . import cable, constants, detection, exceptions, gnss, janusprocessing,\
#       2         saveandload, sensitivity, utils, visualisation
#       4 __all__ = ["cable", "constants", "detection", "exceptions", "gnss",
#       5     "janusprocessing", "saveandload", "sensitivity",
#       6     "utils", "visualisation"]
#
# File ~\Documents\PythonProjects\my-project\libs\dasprocessor\cable.py:6
#       3 from scipy.fft import rfftfreq
#       4 from scipy.signal import convolve, ShortTimeFFT
# ----> 6 from dasprocessor.constants import get_run
#       7 from dasprocessor.janusprocessing import get_all_packets
# ...
