# %%
import os, sys
print("PYTHONPATH =", os.getenv("PYTHONPATH"))
# Out:
# PYTHONPATH = C:\Users\helen\Documents\PythonProjects\my-project\libs

# %%
from pathlib import Path
import json
import math

from dasprocessor.delete_check.bearing_tools import (
    build_subarrays,
    get_cached_channel_gps_for_run,
    subarray_centers_and_headings,
    geojson_subarray_centers,
)

# --- inputs ---
run_number = 2
centers = [112, 208, 268, 552]
aperture_len = 9  # must be odd

# 1) Build subarrays (list of channels per center)
subarrays = build_subarrays(centers, aperture_len, run_number)

# 2) Per-channel GPS for this run (cached)
gps = get_cached_channel_gps_for_run(run_number)

# 3) Compute center lat/lon and heading (deg from North, clockwise)
meta = subarray_centers_and_headings(subarrays, gps)

# Pretty print
def fmt_deg(d):
    return f"{d:7.3f}" if math.isfinite(d) else "   nan"

print("Center  |  Lat (deg)   Lon (deg)   Heading (deg from North)")
print("--------+---------------------------------------------------")
for c in centers:
    m = meta[c]
    print(f"{c:6d} | {fmt_deg(m['center_lat'])}   {fmt_deg(m['center_lon'])}       {fmt_deg(m['heading_deg'])}")

# 4) (Optional) Save to GeoJSON for quick mapping in QGIS/Folium
geo = geojson_subarray_centers(meta)
out_path = Path("subarray_centers_run2.geojson")
with out_path.open("w", encoding="utf-8") as f:
    json.dump(geo, f, indent=2)
print(f"\nGeoJSON saved to: {out_path.resolve()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 21
#      18 subarrays = build_subarrays(centers, aperture_len, run_number)
#      20 # 2) Per-channel GPS for this run (cached)
# ---> 21 gps = get_cached_channel_gps_for_run(run_number)
#      23 # 3) Compute center lat/lon and heading (deg from North, clockwise)
#      24 meta = subarray_centers_and_headings(subarrays, gps)
#
# File ~\Documents\PythonProjects\my-project\libs\dasprocessor\bearing_tools.py:667, in get_cached_channel_gps_for_run(run_number)
#     663 """
#     664 Cached version of channel_gps_for_run(run_number).
#     665 """
#     666 if run_number not in _GPS_CACHE:
# --> 667     _GPS_CACHE[run_number] = channel_gps_for_run(run_number)
#     668 return _GPS_CACHE[run_number]
#
# File ~\Documents\PythonProjects\my-project\libs\dasprocessor\bearing_tools.py:135, in channel_gps_for_run(run_number)
#     132 ch_spacing = float(run["channel_distance"])  # meters
#     134 # Load raw cable polyline (lat, lon, alt)
# --> 135 cable_gps = load_cable_geometry('../resources/cable-layout.json')  # (N,3)
#     137 # Compute cumulative distance along cable polyline in gnss.py:
#     138 # We reuse interpolate_coordinates which expects distances and knowns.
#     139 known_latlonalt = np.asarray(cable_gps, dtype=float)
#
# File ~\Documents\PythonProjects\my-project\libs\dasprocessor\saveandload.py:384, in load_cable_geometry(path, key_sequence, lat_lon_alt_order)
#     362 def load_cable_geometry(path,
#     363                         key_sequence=("features",
#     364                                       0,
#     365                                       "geometry",
#     366                                       "coordinates"),
#     367                         lat_lon_alt_order=[1, 0, 2]):
#     368     """Load cable geometry from JSON file.
#     369
#     370     :param path: Path to cable JSON file.
#    (...)
#     382
#     383     """
# --> 384     with open(path, 'r') as fid:
#     385         obj = json.load(fid)
#     387     for k in key_sequence:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../resources/cable-layout.json'
